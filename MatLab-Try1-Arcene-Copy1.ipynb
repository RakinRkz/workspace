# %%
import scipy.io
import pandas as pd
from caim import CAIMD

# %%
datasetFileName = 'Isolet.mat'

# %%
inp = './datasets/' + datasetFileName
mat = scipy.io.loadmat(inp)

# %%
#mat = {k:v for k, v in mat.items() if k[0] != '_'}
#data = pd.DataFrame({k: pd.Series(v[0]) for k, v in mat.iteritems()})
#mat = {k: v for k, v in mat.items() if not k.startswith('__')}
#data = pd.DataFrame({k: pd.Series(v[0]) for k, v in mat.items()})
#data.to_csv(out)
mat = {k:v for k, v in mat.items() if k[0] != '_'}
data = pd.DataFrame({k: pd.Series(v[0]) for k, v in mat.items()})

# %%
data.head()
# Out:
#         X    Y
# 0 -0.4394  1.0
# 1 -0.0930  NaN
# 2  0.1718  NaN
# 3  0.4620  NaN
# 4  0.6226  NaN

# %%
mat
# Out:
# {'X': array([[-0.4394, -0.093 ,  0.1718, ...,  0.641 ,  0.5898, -0.4872],
#         [-0.4348, -0.1198,  0.2474, ...,  0.4318,  0.4546, -0.091 ],
#         [ 0.0362,  0.751 ,  0.7188, ..., -0.0148, -0.3676, -0.7942],
#         ...,
#         [-0.2776,  0.2344,  0.8278, ...,  0.0184, -0.1902, -0.3988],
#         [-0.1514,  0.2626,  0.8922, ..., -0.0646,  0.    , -0.4516],
#         [-0.347 , -0.047 ,  0.6442, ...,  0.3058,  0.2066, -0.124 ]]),
#  'Y': array([[ 1],
#         [ 1],
#         [ 1],
#         ...,
#         [26],
#         [26],
#         [26]], dtype=uint8)}

# %%
p = mat["X"]
q = mat["Y"]

# %%
df = pd.DataFrame(p)

# %%
df
# Out:
#          0       1       2       3       4       5       6       7       8    \
# 0    -0.4394 -0.0930  0.1718  0.4620  0.6226  0.4704  0.3578  0.0478 -0.1184
# 1    -0.4348 -0.1198  0.2474  0.4036  0.5026  0.6328  0.4948  0.0338 -0.0520
# 2     0.0362  0.7510  0.7188  1.0000  0.9358  0.9840  0.8072  0.4338  0.2290
# 3     0.0220  0.6740  0.6082  0.9122  0.7680  1.0000  0.7932  0.5204  0.1786
# 4    -0.9100 -0.3870 -0.3066  0.2048  0.1928  0.6852  0.5644  0.2782  0.1810
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 1555 -0.0530  0.4206  1.0000  0.9814 -0.0778 -0.3084 -0.3208 -0.5016 -0.5514
# 1556 -0.2220  0.2000  0.9692  1.0000  0.2176 -0.0506 -0.2176 -0.3230 -0.2396
# 1557 -0.2776  0.2344  0.8278  1.0000  0.6364 -0.0862 -0.2966 -0.4066 -0.5168
# 1558 -0.1514  0.2626  0.8922  0.8886 -0.1966 -0.4714 -0.4608 -0.7670 -0.6244
# 1559 -0.3470 -0.0470  0.6442  0.6442 -0.2412 -0.5058 -0.5176 -0.3676 -0.4882
#
# ...

# %%
ff = pd.DataFrame(q)

# %%
ff
# Out:
#        0
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# ...   ..
# 1555  26
# 1556  26
# 1557  26
# 1558  26
# 1559  26
#
# [1560 rows x 1 columns]

# %%
ff.head
# Out:
# <bound method NDFrame.head of        0
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# ...   ..
# 1555  26
# 1556  26
# 1557  26
# 1558  26
# 1559  26
#
# [1560 rows x 1 columns]>

# %%
df.head
# Out:
# <bound method NDFrame.head of          0       1       2       3       4       5       6       7       8    \
# 0    -0.4394 -0.0930  0.1718  0.4620  0.6226  0.4704  0.3578  0.0478 -0.1184
# 1    -0.4348 -0.1198  0.2474  0.4036  0.5026  0.6328  0.4948  0.0338 -0.0520
# 2     0.0362  0.7510  0.7188  1.0000  0.9358  0.9840  0.8072  0.4338  0.2290
# 3     0.0220  0.6740  0.6082  0.9122  0.7680  1.0000  0.7932  0.5204  0.1786
# 4    -0.9100 -0.3870 -0.3066  0.2048  0.1928  0.6852  0.5644  0.2782  0.1810
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 1555 -0.0530  0.4206  1.0000  0.9814 -0.0778 -0.3084 -0.3208 -0.5016 -0.5514
# 1556 -0.2220  0.2000  0.9692  1.0000  0.2176 -0.0506 -0.2176 -0.3230 -0.2396
# 1557 -0.2776  0.2344  0.8278  1.0000  0.6364 -0.0862 -0.2966 -0.4066 -0.5168
# 1558 -0.1514  0.2626  0.8922  0.8886 -0.1966 -0.4714 -0.4608 -0.7670 -0.6244
# 1559 -0.3470 -0.0470  0.6442  0.6442 -0.2412 -0.5058 -0.5176 -0.3676 -0.4882
#
# ...

# %%
x= df
y = ff

# %%
# data = x_disc
data = x
data['class'] = y
print(data.shape)
# Out:
# (1560, 618)

# %%
data.head()
# Out:
#         0       1       2       3       4       5       6       7       8  \
# 0 -0.4394 -0.0930  0.1718  0.4620  0.6226  0.4704  0.3578  0.0478 -0.1184
# 1 -0.4348 -0.1198  0.2474  0.4036  0.5026  0.6328  0.4948  0.0338 -0.0520
# 2  0.0362  0.7510  0.7188  1.0000  0.9358  0.9840  0.8072  0.4338  0.2290
# 3  0.0220  0.6740  0.6082  0.9122  0.7680  1.0000  0.7932  0.5204  0.1786
# 4 -0.9100 -0.3870 -0.3066  0.2048  0.1928  0.6852  0.5644  0.2782  0.1810
#
#         9  ...     608     609     610     611     612     613     614  \
# 0 -0.2310  ...  0.4102  0.2052  0.3846  0.3590  0.5898  0.3334  0.6410
# 1 -0.1302  ...  0.0000  0.2954  0.2046  0.4772  0.0454  0.2046  0.4318
# 2  0.2088  ...  0.2206  0.5882  0.4412 -0.1470 -0.0148  0.0294 -0.0148
# 3  0.1568  ...  0.1216  0.2162 -0.0270 -0.1352 -0.1756 -0.4730 -0.3648
# 4  0.2072  ...  0.0000 -0.2808 -0.4736 -0.3508 -0.3860 -0.4210 -0.2280
#
#       615     616  class
# 0  0.5898 -0.4872      1
# 1  0.4546 -0.0910      1
# ...

# %%
class_column = 'class'      #might need to edit this depending on dataset's target or class' name
feature_list = data
feature_list =  feature_list.drop(class_column, axis=1)
feature_list = feature_list.columns

x = data[feature_list]
y = data[class_column]

feature_list = data.columns
caim = CAIMD()

x_disc = caim.fit_transform(x, y)
data = x_disc
# Out:
# Categorical [419, 446, 448, 449, 450, 451, 577, 578, 579, 580, 581, 582, 584]
# # 0  GLOBAL CAIM  1.6627830045641792
# Processed 1 out of 617 features.
# # 3  GLOBAL CAIM  2.0605735112000865
# Processed 2 out of 617 features.
# # 1  GLOBAL CAIM  1.6976873044462066
# Processed 3 out of 617 features.
# # 2  GLOBAL CAIM  1.9059459305261561
# Processed 4 out of 617 features.
# # 5  GLOBAL CAIM  2.506104393463279
# Processed 5 out of 617 features.
# # 6  GLOBAL CAIM  2.641110104048667
# Processed 6 out of 617 features.
# # 8  GLOBAL CAIM  3.8572799311202393
# Processed 7 out of 617 features.
# # 4  GLOBAL CAIM  2.248866009357717
# Processed 8 out of 617 features.
# # 10  GLOBAL CAIM  3.4415236096598423
# Processed 9 out of 617 features.
# # 9  GLOBAL CAIM  3.892936574478757
# Processed 10 out of 617 features.
# # 7  GLOBAL CAIM  3.3641994669605477
# Processed 11 out of 617 features.
# # 11  GLOBAL CAIM  3.6065126476987723
# Processed 12 out of 617 features.
# ...

# %%
data[class_column] = y 
print(data.shape)
data.to_csv(f'../datasets/{datasetFileName.split('.')[0]}_discretized.csv', index=False)
